# %%
import pandas as pd

df = pd.read_csv('~/Downloads/nyc-calendar.csv', nrows=50)
df.to_csv('../data/nyc/nyc-calendar-sample.csv', index=False)
df = pd.read_csv('~/Downloads/nyc-listings-detailed.csv', nrows=10)
df.to_csv('../data/nyc/nyc-listings-detailed-insideairbnb-sample.csv', index=False)
df = pd.read_csv('~/Downloads/nyc-reviews.csv', nrows=50)
df.to_csv('../data/nyc/nyc-reviews-sample.csv', index=False)

# %%
df = pd.read_csv('~/Downloads/nyc-reviews-detailed.csv', nrows=20)
df.to_csv('../data/nyc/nyc-reviews-detailed-insideairbnb-sample.csv', index=False)

# %%
df = pd.read_csv('../data/nyc/nyc-listings-insideairbnb-summary.csv', nrows=10).to_csv('../data/nyc/nyc-listings-insideairbnb-summary-sample.csv', index=False)

# %%
df = pd.read_csv('~/Downloads/nyc-reviews-detailed.csv', usecols=['date'],parse_dates=['date'])

# %%
df
# Out:
#              date
# 0      2015-12-04
# 1      2016-08-27
# 2      2016-10-01
# 3      2017-02-20
# 4      2017-03-19
# ...           ...
# 977454 2025-07-15
# 977455 2025-07-15
# 977456 2025-07-18
# 977457 2025-07-19
# 977458 2025-07-25
#
# [977459 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# Assuming df is the DataFrame from the previous cell with 'date' column
review_counts = df.groupby('date').size()

plt.figure(figsize=(12, 6))
review_counts.plot()
plt.xlabel('Date')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews by Date')
plt.show()

# %%
df = pd.read_csv('../data/nyc/nyc-listings-detailed-insideairbnb-sample.csv', nrows=3)

# %%
df
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2539  https://www.airbnb.com/rooms/2539  20250801203054   2025-08-03
# 1  2595  https://www.airbnb.com/rooms/2595  20250801203054   2025-08-02
# 2  6848  https://www.airbnb.com/rooms/6848  20250801203054   2025-08-03
#
#         source                                              name  \
# 0  city scrape  Superfast Wi-Fi.  Clean & quiet home by the park
# 1  city scrape           Skylit Studio Oasis | Midtown Manhattan
# 2  city scrape                  Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Bright, serene room in a renovated apartment h...
# 1  Prime Midtown | Spacious 500 Sq Ft | Pyramid S...
# 2  Comfortable studio apartment with super comfor...
#
#                                neighborhood_overview  \
# 0    Close to Prospect Park and Historic Ditmas Park
# 1  Centrally located in the heart of Manhattan ju...
# ...

# %%
df = pd.read_csv('~/Downloads/nyc-listings-detailed-insideairbnb.csv')

# %%
df.shape
# Out:
# (36403, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36403 entries, 0 to 36402
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            36403 non-null  int64
#  1   listing_url                                   36403 non-null  object
#  2   scrape_id                                     36403 non-null  int64
#  3   last_scraped                                  36403 non-null  object
#  4   source                                        36403 non-null  object
#  5   name                                          36401 non-null  object
#  6   description                                   35452 non-null  object
#  7   neighborhood_overview                         19067 non-null  object
#  8   picture_url                                   36403 non-null  object
# ...
